# %% [markdown]
# <a href="https://colab.research.google.com/github/Drack-AS/uas-VDI/blob/main/uas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import PercentFormatter

# %%
df_kpbulanan = pd.read_csv("/content/kebutuhan_per_bulan_2.csv")

# %%
df_kpbulanan
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %% [markdown]
# Scater plot 1

# %%
df = pd.DataFrame(df_kpbulanan)

provinsi_tertentu = 'ACEH'
df_provinsi_tertentu = df.loc[df['Propinsi'] == provinsi_tertentu]

x = df_provinsi_tertentu['tahun']
y = df_provinsi_tertentu['kebutuhan']

plt.title(f'STATISTIK KEBUTUHAN {provinsi_tertentu}')
plt.xlabel("Tahun")
plt.ylabel("Kebutuhan")

plt.scatter(x, y, color='#D04', marker='s')

plt.xlim(min(x), max(x))


plt.show()

# %% [markdown]
# Scater Plot 2

# %%
df = pd.DataFrame(df_kpbulanan)
tahun = 2014
df_provinsi_tertentu = df.loc[df['tahun'] == tahun]
df_sorted = df_provinsi_tertentu.sort_values(by='kebutuhan', ascending=False)
df_data = df_sorted.head(5)

x = df_data['Propinsi']
y = df_data['kebutuhan']

df_provinsi_tertentu
plt.title(f'data kebutuhan 5 provinsi tertinggi di tahun 2014')

plt.scatter(x, y, color='#D04', marker='s')

# %% [markdown]
# Scater plot 3

# %%
df_supply = pd.read_csv("/content/SupplyKantor.csv")

# %%
df_supply
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...
